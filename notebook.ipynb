# %% [markdown]
# # Get api key from
# https://aistudio.google.com/app/apikey

# %% [markdown]
# # Course url
# https://learn.nvidia.com/courses/course-detail?course_id=course-v1:DLI+S-FX-15+V1

# %% [markdown]
# # Printing the models

# %%
# Direct Google Gemini API Usage
import google.generativeai as genai

for m in genai.list_models():
    if "generateContent" in m.supported_generation_methods:
        print(m.name)
# Out:
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-pro-exp-0801
# models/gemini-1.5-pro-exp-0827
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-exp-0827
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924

# %% [markdown]
# # Printing the embedders of gemini

# %%
for m in genai.list_models():
    if "embedContent" in m.supported_generation_methods:
        print(m.name)
# Out:
# models/embedding-001
# models/text-embedding-004

# %% [markdown]
# # Getting information about a model

# %%
model_info = genai.get_model("models/embedding-001")
print(model_info)
# Out:
# Model(name='models/embedding-001',
#       base_model_id='',
#       version='001',
#       display_name='Embedding 001',
#       description='Obtain a distributed representation of a text.',
#       input_token_limit=2048,
#       output_token_limit=1,
#       supported_generation_methods=['embedContent'],
#       temperature=None,
#       max_temperature=None,
#       top_p=None,
#       top_k=None)

# %% [markdown]
# # Reading the pdf

# %%
import PyPDF2

# Open the PDF file
pdf_path = 'herman-melville-moby-dick.pdf'
with open(pdf_path, 'rb') as file:
    reader = PyPDF2.PdfReader(file)
    text = ''
    for page_num in range(len(reader.pages)):
        page = reader.pages[page_num]
        text += page.extract_text()

# %% [markdown]
# # Splitting the book to chuncks and summarize them

# %%
from langchain_google_genai import GoogleGenerativeAI, GoogleGenerativeAIEmbeddings
from typing import List,Tuple
import time
import os
from tenacity import (retry,stop_after_attempt,wait_fixed,retry_if_exception_type,before_sleep_log)
import logging

# Set up logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

def get_wait_time(retry_count: int) -> float:
    """Return wait time based on retry count"""
    if retry_count <= 3:
        return 4.0
    elif retry_count == 4:
        return 8.0
    else:
        return 10.0

class CustomWaitStrategy:
    """Custom wait strategy that follows the exact pattern from error messages"""
    def __init__(self):
        self.retry_count = 0

    def __call__(self, retry_state):
        self.retry_count += 1
        wait_time = get_wait_time(self.retry_count)
        return wait_time

# Set your API key
def init_google_api(api_key: str):
    """Initialize Google API key"""
    os.environ["GOOGLE_API_KEY"] = api_key

@retry(
    wait=CustomWaitStrategy(),
    stop=stop_after_attempt(5),
    retry=retry_if_exception_type(Exception),
    before_sleep=before_sleep_log(logger, logging.INFO)
)
def summarize_chunk(chunk: str, llm) -> str:
    """Summarize text using Gemini with exact retry timing"""
    try:
        prompt = f"""Please summarize the following text concisely in no more than 2-3 sentences:
        
        {chunk}
        
        Summary:"""
        
        return llm.invoke(prompt)
    except Exception as e:
        logger.error(f"Error during summarization: {str(e)}")
        raise

@retry(
    wait=CustomWaitStrategy(),
    stop=stop_after_attempt(5),
    retry=retry_if_exception_type(Exception),
    before_sleep=before_sleep_log(logger, logging.INFO)
)
def get_embedding(text: str, embeddings_model) -> List[float]:
    """Get embeddings using Google's embedding model with exact retry timing"""
    try:
        return embeddings_model.embed_query(text)
    except Exception as e:
        logger.error(f"Error during embedding: {str(e)}")
        raise

def process_text_chunks(chunks: List[str], api_key: str, batch_size: int = 2) -> tuple:
    """Process text chunks with conservative batching"""
    # Initialize API key
    init_google_api(api_key)
    
    # Initialize models
    llm = GoogleGenerativeAI(
        model="gemini-pro",  # Correct model name format
        temperature=0,
        top_p=0.8,
        google_api_key=api_key,
        max_output_tokens=750
    )
    
    embeddings_model = GoogleGenerativeAIEmbeddings(
        model="models/embedding-001",
        google_api_key=api_key
    )
    
    summaries = []
    embeddings = []
    
    # Process in batches
    for i in range(0, len(chunks), batch_size):
        batch = chunks[i:i + batch_size]
        logger.info(f"\nProcessing batch {i//batch_size + 1}/{(len(chunks) + batch_size - 1)//batch_size}")
        
        # Generate summaries for batch
        for chunk in batch:
            logger.info("Summarizing chunk...")
            summary = summarize_chunk(chunk, llm)
            summaries.append(summary)
            # Add mandatory wait between API calls
            time.sleep(4.0)
        
        # Generate embeddings for batch
        for summary in summaries[i:i + batch_size]:
            logger.info("Generating embedding...")
            embedding = get_embedding(summary, embeddings_model)
            embeddings.append(embedding)
            # Add mandatory wait between API calls
            time.sleep(4.0)
        
        # Add longer wait between batches
        if i + batch_size < len(chunks):
            logger.info("Waiting between batches...")
            time.sleep(8.0)
    
    return summaries, embeddings

def chunk_text(text: str, max_chunk_size: int = 750) -> List[str]:
    """Split text into chunks of appropriate size"""
    words = text.split()
    chunks = []
    current_chunk = []
    current_size = 0
    
    for word in words:
        word_size = len(word) + 1  # +1 for space
        if current_size + word_size > max_chunk_size:
            chunks.append(' '.join(current_chunk))
            current_chunk = [word]
            current_size = word_size
        else:
            current_chunk.append(word)
            current_size += word_size
    
    if current_chunk:
        chunks.append(' '.join(current_chunk))
    
    return chunks
# Your Google API key
API_KEY = "YOUR_API_KEY"
long_text = text
try:
    # Create chunks with specified size
    chunks = chunk_text(long_text, max_chunk_size=15000)
    # Process the chunks
    summaries, embeddings = process_text_chunks(
        chunks=chunks,
        api_key=API_KEY,
        batch_size=2
    )
    # Print results
    for i, (summary, embedding) in enumerate(zip(summaries, embeddings)):
        print(f"\nChunk {i+1} Summary:")
        print(summary)
        print(f"Embedding dimension: {len(embedding)}")   
except Exception as e:
    logger.error(f"An error occurred: {str(e)}")
# Out:
# INFO:__main__:
# Processing batch 1/37
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Generating embedding...
# INFO:__main__:Generating embedding...
# INFO:__main__:Waiting between batches...
# INFO:__main__:
# Processing batch 2/37
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Generating embedding...
# INFO:__main__:Generating embedding...
# INFO:__main__:Waiting between batches...
# INFO:__main__:
# Processing batch 3/37
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Generating embedding...
# INFO:__main__:Generating embedding...
# INFO:__main__:Waiting between batches...
# INFO:__main__:
# Processing batch 4/37
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Generating embedding...
# INFO:__main__:Generating embedding...
# INFO:__main__:Waiting between batches...
# INFO:__main__:
# Processing batch 5/37
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Generating embedding...
# INFO:__main__:Generating embedding...
# INFO:__main__:Waiting between batches...
# INFO:__main__:
# Processing batch 6/37
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Generating embedding...
# INFO:__main__:Generating embedding...
# INFO:__main__:Waiting between batches...
# INFO:__main__:
# Processing batch 7/37
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Generating embedding...
# INFO:__main__:Generating embedding...
# INFO:__main__:Waiting between batches...
# INFO:__main__:
# Processing batch 8/37
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Generating embedding...
# INFO:__main__:Generating embedding...
# INFO:__main__:Waiting between batches...
# INFO:__main__:
# Processing batch 9/37
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Generating embedding...
# INFO:__main__:Generating embedding...
# INFO:__main__:Waiting between batches...
# INFO:__main__:
# Processing batch 10/37
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Generating embedding...
# INFO:__main__:Generating embedding...
# INFO:__main__:Waiting between batches...
# INFO:__main__:
# Processing batch 11/37
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Generating embedding...
# INFO:__main__:Generating embedding...
# INFO:__main__:Waiting between batches...
# INFO:__main__:
# Processing batch 12/37
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Generating embedding...
# INFO:__main__:Generating embedding...
# INFO:__main__:Waiting between batches...
# INFO:__main__:
# Processing batch 13/37
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Generating embedding...
# INFO:__main__:Generating embedding...
# INFO:__main__:Waiting between batches...
# INFO:__main__:
# Processing batch 14/37
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Generating embedding...
# INFO:__main__:Generating embedding...
# INFO:__main__:Waiting between batches...
# INFO:__main__:
# Processing batch 15/37
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Generating embedding...
# INFO:__main__:Generating embedding...
# INFO:__main__:Waiting between batches...
# INFO:__main__:
# Processing batch 16/37
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Generating embedding...
# INFO:__main__:Generating embedding...
# INFO:__main__:Waiting between batches...
# INFO:__main__:
# Processing batch 17/37
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Generating embedding...
# INFO:__main__:Generating embedding...
# INFO:__main__:Waiting between batches...
# INFO:__main__:
# Processing batch 18/37
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Generating embedding...
# INFO:__main__:Generating embedding...
# INFO:__main__:Waiting between batches...
# INFO:__main__:
# Processing batch 19/37
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Generating embedding...
# INFO:__main__:Generating embedding...
# INFO:__main__:Waiting between batches...
# INFO:__main__:
# Processing batch 20/37
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Generating embedding...
# INFO:__main__:Generating embedding...
# INFO:__main__:Waiting between batches...
# INFO:__main__:
# Processing batch 21/37
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Generating embedding...
# INFO:__main__:Generating embedding...
# INFO:__main__:Waiting between batches...
# INFO:__main__:
# Processing batch 22/37
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Generating embedding...
# INFO:__main__:Generating embedding...
# INFO:__main__:Waiting between batches...
# INFO:__main__:
# Processing batch 23/37
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Generating embedding...
# INFO:__main__:Generating embedding...
# INFO:__main__:Waiting between batches...
# INFO:__main__:
# Processing batch 24/37
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Generating embedding...
# INFO:__main__:Generating embedding...
# INFO:__main__:Waiting between batches...
# INFO:__main__:
# Processing batch 25/37
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Generating embedding...
# INFO:__main__:Generating embedding...
# INFO:__main__:Waiting between batches...
# INFO:__main__:
# Processing batch 26/37
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Generating embedding...
# INFO:__main__:Generating embedding...
# INFO:__main__:Waiting between batches...
# INFO:__main__:
# Processing batch 27/37
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Generating embedding...
# INFO:__main__:Generating embedding...
# INFO:__main__:Waiting between batches...
# INFO:__main__:
# Processing batch 28/37
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Generating embedding...
# INFO:__main__:Generating embedding...
# INFO:__main__:Waiting between batches...
# INFO:__main__:
# Processing batch 29/37
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Generating embedding...
# INFO:__main__:Generating embedding...
# INFO:__main__:Waiting between batches...
# INFO:__main__:
# Processing batch 30/37
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Generating embedding...
# INFO:__main__:Generating embedding...
# INFO:__main__:Waiting between batches...
# INFO:__main__:
# Processing batch 31/37
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Generating embedding...
# INFO:__main__:Generating embedding...
# INFO:__main__:Waiting between batches...
# INFO:__main__:
# Processing batch 32/37
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Generating embedding...
# INFO:__main__:Generating embedding...
# INFO:__main__:Waiting between batches...
# INFO:__main__:
# Processing batch 33/37
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Generating embedding...
# INFO:__main__:Generating embedding...
# INFO:__main__:Waiting between batches...
# INFO:__main__:
# Processing batch 34/37
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Generating embedding...
# INFO:__main__:Generating embedding...
# INFO:__main__:Waiting between batches...
# INFO:__main__:
# Processing batch 35/37
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Generating embedding...
# INFO:__main__:Generating embedding...
# INFO:__main__:Waiting between batches...
# INFO:__main__:
# Processing batch 36/37
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Generating embedding...
# INFO:__main__:Generating embedding...
# INFO:__main__:Waiting between batches...
# INFO:__main__:
# Processing batch 37/37
# INFO:__main__:Summarizing chunk...
# INFO:__main__:Generating embedding...
# Chunk 1 Summary:
# Herman Melville's "Moby-Dick" is a sprawling novel that follows the obsessive quest of Captain Ahab to hunt down the elusive white whale, Moby Dick. The narrative is narrated by Ishmael, a sailor who joins Ahab's crew on the whaling ship Pequod. The novel explores themes of obsession, revenge, and the human condition, and features a vast cast of characters and vivid descriptions of whaling life.
# Embedding dimension: 768
#
# Chunk 2 Summary:
# The narrator, Ishmael, embarks on a whaling voyage to escape the mundane and embrace the wonders of the sea. He arrives in New Bedford and finds lodging at the dilapidated "Spouter-Inn," where he encounters a mysterious painting depicting a whale impaling itself on a ship's masts during a hurricane. The inn's interior is adorned with macabre whaling artifacts, including a whale's jawbone serving as a bar.
# Embedding dimension: 768
#
# Chunk 3 Summary:
# At a dismal inn, the narrator encounters a group of rowdy sailors, including a mysterious harpooneer who is rumored to be selling human heads. Despite his reservations, the narrator agrees to share a bed with the harpooneer, but his suspicions are aroused by the man's strange behavior and the presence of a peculiar door mat in the room.
# Embedding dimension: 768
#
# Chunk 4 Summary:
# After a restless night, the narrator finds himself sharing a bed with Queequeg, a tattooed cannibal harpooneer. Despite his initial fear, the narrator realizes that Queequeg is harmless and even kind, and they form an unlikely bond. The narrator's initial discomfort at Queequeg's appearance and strange rituals gradually gives way to acceptance and understanding.
# Embedding dimension: 768
#
# Chunk 5 Summary:
# After an awkward encounter with his tattooed companion Queequeg, the narrator observes the diverse and eccentric characters in New Bedford, a town heavily influenced by the whaling industry. He visits the Whaleman's Chapel, where he encounters Queequeg and witnesses the somber atmosphere created by memorial tablets honoring deceased sailors. Despite the grim reminders of the dangers of whaling, the narrator finds solace in the belief that his true essence lies beyond his physical body.
# Embedding dimension: 768
#
# Chunk 6 Summary:
# Father Mapple, a former seafarer, delivers a sermon in a unique pulpit adorned with maritime elements, symbolizing the church's role as a spiritual stronghold and the pulpit's position as the "foremost part" of the world. The sermon, based on the story of Jonah, explores the themes of disobedience, flight from God, and the consequences of sin, highlighting the importance of obedience and repentance.
# Embedding dimension: 768
#
# Chunk 7 Summary:
# Jonah's disobedience to God leads to a violent storm at sea, prompting the sailors to cast him overboard. Despite his initial resistance, Jonah is swallowed by a whale and eventually repents, leading to his deliverance. The preacher uses Jonah's story to emphasize the importance of repentance and the dangers of ignoring God's commands.
# Embedding dimension: 768
#
# Chunk 8 Summary:
# Ishmael and Queequeg, a cannibal from Kokovoko, form an unlikely friendship after sharing a smoke. Queequeg, despite his initial reluctance, agrees to join Ishmael on a whaling voyage, hoping to learn from Christians and improve his people's lives. Despite the prejudices of others, Ishmael and Queequeg's bond deepens as they share a bed and confidences, with Queequeg revealing his desire to return home and use his newfound knowledge for good.
# Embedding dimension: 768
#
# Chunk 9 Summary:
# During a banquet on Nantucket, Captain Ahab's reckless hand-washing in the punch bowl amuses Queequeg. As the schooner Moss sails, Queequeg rescues a drowning man, earning the respect of the crew. The narrator reflects on the seafaring nature of the Nantucketers, who have conquered the oceans and made it their home.
# Embedding dimension: 768
#
# Chunk 10 Summary:
# After enjoying a delicious chowder, Ishmael and Queequeg decide to select a whaling ship. Despite Ishmael's preference for Queequeg's guidance, Queequeg insists on leaving the choice to Yojo, his god. Ishmael reluctantly agrees and embarks on a search, eventually choosing the Pequod, an old and peculiar vessel with a mysterious captain named Ahab.
# Embedding dimension: 768
#
# Chunk 11 Summary:
# In Nantucket, whaling is a lucrative industry, and many residents invest in whaling vessels. Captain Bildad, a retired Quaker whaleman, is known for his strict adherence to Quaker principles despite his involvement in the bloody whaling trade. Captain Peleg, another ship owner, is a more boisterous and irreverent character. Despite their differences, they jointly manage the Pequod, a whaling ship that Ishmael, the narrator, signs on to join.
# Embedding dimension: 768
#
# Chunk 12 Summary:
# Captain Ahab, the enigmatic and formidable captain of the Pequod, is described as a complex and enigmatic figure. Despite his reputation as a skilled whaler and a stern leader, he is also known for his obsessive pursuit of the white whale, Moby Dick, which cost him his leg. While some crew members express concern about his mental state, others remain loyal, recognizing his determination and leadership qualities.
# Embedding dimension: 768
#
# Chunk 13 Summary:
# An enigmatic sailor named Elijah follows Queequeg and the narrator, raising suspicions about his intentions. Despite the impending departure of the Pequod, Captain Ahab remains unseen, leaving Captains Peleg and Bildad in charge of preparations. As the crew gathers, the absence of Ahab is explained as due to his recovery from an illness.
# Embedding dimension: 768
#
# Chunk 14 Summary:
# As the Pequod sets sail, Captain Peleg and pilot Bildad bid farewell to the crew, despite their initial reluctance to leave. The ship's departure is marked by a sense of both excitement and trepidation, as the crew faces the unknown dangers of the ocean. The chapter also introduces Bulkington, a seasoned mariner who embodies the restless spirit of those who seek adventure despite the perils it entails.
# Embedding dimension: 768
#
# Chunk 15 Summary:
# Whaling has played a significant role in history, contributing to the liberation of South American colonies, the discovery of Australia, and the spread of commerce and missionary work. Despite its lack of literary recognition, whaling is a noble profession, as evidenced by the bravery and resilience of its practitioners. The crew of the Pequod includes Starbuck, a cautious and superstitious Quaker, and Stubb, a carefree and unfearing Cape Cod man.
# Embedding dimension: 768
#
# Chunk 16 Summary:
# The three mates of the Pequod, Starbuck, Stubb, and Flask, are described as distinct and capable individuals. Stubb's constant smoking is believed to protect him from the negative energies of the dead, while Flask's fearlessness and joviality make him a skilled whale hunter. The harpooneers, Queequeg, Tashtego, and Daggoo, are also introduced, each with their unique backgrounds and physical attributes.
# Embedding dimension: 768
#
# Chunk 17 Summary:
# As the Pequod sailed through the pleasant spring weather, Ahab's mood gradually improved, and he began to show signs of warmth and humanity. However, his encounter with Stubb, who questioned his authority, revealed a deep-seated anger and a sense of isolation within Ahab.
# Embedding dimension: 768
#
# Chunk 18 Summary:
# Herman Melville's "Moby-Dick" presents a comprehensive classification system for whales, dividing them into three primary categories based on size: Folio, Octavo, and Duodecimo. The Folio category includes the Sperm Whale, Right Whale, Fin-Back Whale, Hump-backed Whale, Razor Back Whale, and Sulphur Bottom Whale. Melville emphasizes the importance of external characteristics, such as the horizontal tail, in defining whales and acknowledges the challenges of classifying them based on internal anatomy.
# Embedding dimension: 768
#
# Chunk 19 Summary:
# The text describes various whale species, including the Razorback, Sulphur Bottom, Grampus, Black Fish, Narwhale, Killer, Thrasher, Huzza Porpoise, Algerine Porpoise, and Mealy-mouthed Porpoise. These whales vary in size, appearance, and behavior, with some being valuable for their oil and others being elusive or aggressive. The text also mentions the Specksynder, a historical whale-hunting officer who held authority over the harpooners and the whale-hunting department.
# Embedding dimension: 768
#
# Chunk 20 Summary:
# Despite the long and perilous nature of whaling voyages, the strict discipline and formal etiquette of the quarterdeck are maintained on Nantucket ships, even by the enigmatic Captain Ahab. At the dinner table, the officers and harpooneers observe a rigid hierarchy, with Ahab presiding in silence while his subordinates deferentially await their portions. The harpooneers, in contrast, enjoy a boisterous and informal meal, highlighting the stark differences in social status and behavior aboard the Pequod.
# Embedding dimension: 768
#
# Chunk 21 Summary:
# In the Pequod, the cabin was primarily reserved for Captain Ahab, who lived in isolation and seclusion. The mates and harpooneers spent most of their time outside the cabin, as they were not considered part of the ship's social hierarchy. The mast-head, where lookouts stood watch, was a place of solitude and contemplation, offering a panoramic view of the vast ocean.
# Embedding dimension: 768
#
# Chunk 22 Summary:
# The narrator describes the mystical connection between humans and nature, where elusive thoughts and emotions manifest as elusive creatures. Ahab, the ship's captain, summons his crew to witness his intense obsession with hunting a white whale named Moby Dick, which he believes has wronged him. Ahab's crew, initially hesitant, is eventually swayed by his fiery determination and agrees to join him in his relentless pursuit.
# Embedding dimension: 768
#
# Chunk 23 Summary:
# Captain Ahab, driven by his obsession with Moby Dick, appoints three harpooneers as cup-bearers and forces them to drink a toast to the whale's destruction. Despite Starbuck's unease, the crew engages in a raucous celebration, while Ahab remains isolated and consumed by his madness. Meanwhile, the sailors on the forecastle dance and sing, oblivious to the impending storm and the ominous signs in the sky.
# Embedding dimension: 768
#
# Chunk 24 Summary:
# The crew of the Pequod, including the narrator Ishmael, is filled with a mix of fear and excitement as they prepare to hunt the legendary White Whale, Moby Dick. Despite rumors of its immense size, ferocity, and supernatural powers, some hunters remain determined to confront the creature, while others are terrified by its reputation. The whale's elusive nature and the numerous fatalities associated with its encounters have instilled a deep sense of dread among whalemen.
# Embedding dimension: 768
#
# Chunk 25 Summary:
#
# Embedding dimension: 768
#
# Chunk 26 Summary:
# The color white evokes a profound sense of awe and terror in humans, as evidenced by the fear inspired by albinos, the "White Squall," and the "White Hoods of Ghent." This phenomenon is attributed to the association of whiteness with death, the supernatural, and the unknown. Despite its symbolic significance in Christianity, whiteness also intensifies the horror of certain objects, such as the "White Tower of London" and the "White Sea."
# Embedding dimension: 768
#
# Chunk 27 Summary:
# During a calm night, Archy, a seaman, hears a noise in the after-hold and suspects someone is hiding there. Captain Ahab, driven by his obsession with Moby Dick, meticulously studies charts and calculates currents to increase his chances of encountering the whale. Despite the vastness of the ocean, Ahab believes he can recognize Moby Dick by its distinctive white brow and hump.
# Embedding dimension: 768
#
# Chunk 28 Summary:
# Despite facing numerous perils, a man and a whale encounter each other twice, with the man ultimately vanquishing the whale. This incident is supported by historical accounts of whales being recognized and hunted over time, including famous whales like Timor Tom and New Zealand Jack. Additionally, the Sperm Whale has been known to possess immense power, capable of sinking ships and causing significant damage.
# Embedding dimension: 768
#
# Chunk 29 Summary:
# During his tenure as prefect of Constantinople, Procopius recorded the capture of a sea monster in the Propontis, which is likely to have been a Sperm Whale based on its destructive behavior and the presence of its food source in the area. Despite his obsession with capturing Moby Dick, Captain Ahab recognized the need to maintain the crew's morale and prevent rebellion by providing them with additional incentives, such as the pursuit of other whales and the promise of financial rewards.
# Embedding dimension: 768
#
# Chunk 30 Summary:
# In the face of adversity, some individuals adopt a carefree attitude, viewing life as a joke and embracing its challenges with a sense of humor. This philosophy is particularly prevalent among whalers, who face constant danger and uncertainty. Despite the risks, they maintain a sense of tranquility and acceptance, as exemplified by the narrator's decision to draft his will and embrace the unknown.
# Embedding dimension: 768
#
# Chunk 31 Summary:
# During a tempestuous voyage around the Cape of Good Hope, the Pequod encounters a ghostly albatross and a mysterious whaling vessel named the Goney. Captain Ahab, driven by his obsession with the White Whale, refuses to board the Goney despite the ominous implications of its appearance. The crew remains silent and fatalistic in the face of the storm, while Ahab stands steadfastly at the helm, his gaze fixed on the horizon.
# Embedding dimension: 768
#
# Chunk 32 Summary:
# In the whaling industry, the captain stands while being rowed, unlike other ships where they sit comfortably. The Town-Ho, a whaling ship, encountered the Pequod and shared news of Moby Dick, including a mysterious and ominous incident involving the captain and a crew member. This secret, known only to a few sailors on the Pequod, would later play a significant role in the tragedy that unfolded.
# Embedding dimension: 768
#
# Chunk 33 Summary:
#
# Embedding dimension: 768
#
# Chunk 34 Summary:
# A mutiny on the whaling ship Town-Ho is thwarted when the leader, Steelkilt, is betrayed by his accomplices and hanged. Despite his revenge plot against the chief mate, Radney, Steelkilt's plan is foiled by a whale attack that kills Radney and allows Moby Dick to escape. The remaining crew deserts, leaving the captain and a small group to struggle with the ship's leak. Steelkilt, having escaped, joins a war canoe and sails to Tahiti, where he boards the captain's boat and forces him to swear to remain on an island for six days.
# Embedding dimension: 768
#
# Chunk 35 Summary:
# A sailor recounts a tale of the white whale that killed his captain, Radney, and the subsequent disappearance of the ship's first mate, Steelkilt. The sailor's account is corroborated by the captain's widow, who still mourns her husband's loss. Despite the story's fantastical elements, the sailor insists on its truthfulness, citing his own experiences and the testimony of Steelkilt.
# Embedding dimension: 768
#
# Chunk 36 Summary:
# The engravings by Garnery and Durand depict the excitement and danger of whaling, capturing the essence of the hunt with remarkable accuracy. Despite their limited experience, French artists have produced the most vivid and authentic representations of whaling scenes, surpassing the mechanical sketches of English and American draughtsmen.
# Embedding dimension: 768
#
# Chunk 37 Summary:
# The sea is a treacherous and unforgiving force, with hidden dangers lurking beneath its serene surface. Like the savage sea, the human soul harbors a dark and unknown side, a "half known life" filled with horrors. The vast and elusive Squid, a mysterious creature of the deep, symbolizes the unknown and potentially dangerous aspects of both the sea and the human psyche.
# Embedding dimension: 768
#
# Chunk 38 Summary:
# In the face of death, philosophers remain calm, recognizing the constant perils of life. During a calm day, the Pequod's crew encounters a giant sperm whale. Stubb, the harpooneer, successfully kills the whale after a fierce battle, using his pipe as a symbol of his composure.
# Embedding dimension: 768
#
# Chunk 39 Summary:
#
# Embedding dimension: 768
#
# Chunk 40 Summary:
# In a conversation with the cook, Stubb questions the morality of eating whale meat, highlighting its excessive richness and the fact that it is consumed by its own light. Despite the unappetizing nature of whale meat, whalers partake of it in various forms, including fried blubber and cooked brains. The process of cutting in involves using massive tackles to strip the blubber from the whale's body, with the crew working in unison to heave and hoist the heavy strips.
# Embedding dimension: 768
#
# Chunk 41 Summary:
# The whale's skin, known as blubber, is an incredibly thick layer that insulates the whale and allows it to survive in cold waters. The exterior of the whale is marked with mysterious hieroglyphics that resemble ancient Indian carvings. The whale's body, after being stripped of its blubber, floats away as a ghostly reminder of its former life, attracting scavengers and instilling fear in passing ships.
# Embedding dimension: 768
#
# Chunk 42 Summary:
# The narrator, tied to Queequeg by a rope, feels a profound connection with him, recognizing the shared dangers and uncertainties of life. Despite the risks, they work together to protect Queequeg from sharks and other hazards. The crew then captures a Right Whale, which is believed to bring good luck to the ship if its head is displayed alongside a Sperm Whale's head.
# Embedding dimension: 768
#
# Chunk 43 Summary:
# Despite his fear of the devil, Flask believes Fedallah plans to kidnap Captain Ahab. Stubb suspects Fedallah's intentions and threatens to restrain him if necessary. Meanwhile, the crew compares the heads of a sperm whale and a right whale, noting their contrasting features, including the sperm whale's superior dignity and the peculiar positioning of its eyes and ears.
# Embedding dimension: 768
#
# Chunk 44 Summary:
# During the whaling process, sailors use a large, soft wad to protect their hands from the impact of the whale's head, which is believed to have a unique connection to the atmosphere. The whale's head contains a vast "Heidelburgh Tun" filled with valuable spermaceti, which is extracted using a bucket and pole. In a dramatic incident, the Indian harpooneer Tashtego falls into the tun but is rescued by Queequeg, who uses his sword to create an opening and retrieve Tashtego.
# Embedding dimension: 768
#
# Chunk 45 Summary:
# The Sperm Whale's physiognomy is enigmatic, lacking a nose but possessing a majestic forehead that evokes awe and a sense of the divine. Phrenologically, its brain is concealed within its massive skull, but its spinal cord is remarkably large, suggesting a strong will and indomitability. The Pequod encounters the German whaling ship Jungfrau, whose captain seeks to borrow oil, highlighting the irony of an oil ship needing oil on the whaling grounds.
# Embedding dimension: 768
#
# Chunk 46 Summary:
# During a fierce whale hunt, the Pequod's boats race to harpoon a massive whale with a missing fin. Despite a valiant effort by the German boat, the Pequod's crew successfully strikes the whale, leading to a chaotic and bloody battle. The whale, severely wounded, eventually succumbs and is secured to the ship, its vast body suspended by lines to prevent it from sinking.
# Embedding dimension: 768
#
# Chunk 47 Summary:
# During the dissection of a whale, a harpoon and a stone lance head were discovered embedded in its flesh, suggesting a mysterious history. Despite efforts to prevent it, the whale's body sank due to its immense weight, but later resurfaced due to the accumulation of gases. The story of Perseus and Andromeda, where Perseus killed a whale to save Andromeda, highlights the ancient and honorable nature of whaling.
# Embedding dimension: 768
#
# Chunk 48 Summary:
# Despite skepticism, the idea of Jonah traveling to Nineveh via the Cape of Good Hope is supported by historical accounts and the belief of the Turks. The whale's spout, a mystery whether it contains water or vapor, is essential for the whale's survival, as it replenishes its oxygen supply. The whale's tail, with its intricate structure and immense strength, is a marvel of engineering, combining power and grace.
# Embedding dimension: 768
#
# Chunk 49 Summary:
# True strength enhances beauty, as exemplified by the muscularity of Hercules and the robustness of Michelangelo's depiction of God. The whale's tail, with its five distinct motions, is a marvel of grace and power, capable of inflicting devastating blows or performing delicate maneuvers. Despite its immense size, the whale remains an enigmatic creature, its face hidden and its gestures often inscrutable.
# Embedding dimension: 768
#
# Chunk 50 Summary:
# As the Pequod pursued a vast fleet of whales through the Straits of Sunda, they encountered a second group of whales in their wake, pursued by Malay pirates. Despite the danger, the Pequod's crew pressed on, driving the whales into a state of panic and confusion. The boats separated to chase individual whales, and Queequeg's harpoon struck one, leading to a perilous chase through the frenzied herd.
# Embedding dimension: 768
#
# Chunk 51 Summary:
#
# Embedding dimension: 768
#
# Chunk 52 Summary:
# The laws of "Fast-Fish" and "Loose-Fish" govern the ownership of whales, with "Fast-Fish" belonging to the party who first harpoons them and "Loose-Fish" being fair game for anyone. However, the English law grants the head of a captured whale to the King and the tail to the Queen, a practice that has been criticized as unfair to fishermen.
# Embedding dimension: 768
#
# Chunk 53 Summary:
# During a calm, the Pequod encounters a French whaling ship, the Bouton de Rose, whose crew is struggling to extract oil from two foul-smelling whales. Stubb, the Pequod's first mate, devises a plan to trick the French captain into believing the whales are worthless, while secretly excavating the body of one whale and discovering valuable ambergris, a fragrant substance used in perfumery.
# Embedding dimension: 768
#
# Chunk 54 Summary:
# Despite the unpleasant odor associated with whaling, sperm whales are not inherently smelly. However, the Pequod's crewman Pip, a timid and clumsy individual, accidentally jumps from a boat during a whale hunt and is left behind in the ocean. Despite Stubb's initial reluctance to rescue him, Pip is eventually saved by the ship, but the experience leaves him traumatized and mentally unstable.
# Embedding dimension: 768
#
# Chunk 55 Summary:
#
# Embedding dimension: 768
#
# Chunk 56 Summary:
# The narrator argues that true wisdom comes from experiencing both joy and sorrow, and that the pursuit of happiness alone is a sign of immaturity. He also describes the whaling industry, highlighting the meticulous care taken in processing whale oil and the subsequent cleansing of the ship, which symbolizes the cyclical nature of life and the constant struggle against adversity. Finally, he examines the doubloon nailed to the mast of the Pequod, which becomes a symbol of Ahab's obsessive pursuit of the white whale and the dangers of egotism.
# Embedding dimension: 768
#
# Chunk 57 Summary:
# The narrator interprets the zodiac signs on a gold coin as a metaphor for the stages of human life, from birth to death. Various crew members offer their own interpretations, including a cannibal who sees the signs in his thigh bone and a madman who recites a nonsensical rhyme. The narrator concludes that the coin represents the ship's "navel" and that unscrewing it would have dire consequences.
# Embedding dimension: 768
#
# Chunk 58 Summary:
# The author provides detailed measurements of a Sperm Whale's skeleton, based on his examination of a specimen at the Arsacidean temple in Tranque. The skeleton, measuring 72 feet in length, includes a 20-foot skull and jaw, 50 feet of backbone, and 10 ribs on each side, with the middle ribs being the longest and most arched. The author notes that the skeleton does not fully represent the whale's living size, as the invested body would have been significantly larger.
# Embedding dimension: 768
#
# Chunk 59 Summary:
# The author argues that the whale's size has not diminished over time, despite fossil evidence suggesting otherwise. While the whale's magnitude may have fluctuated, it remains comparable to its ancient ancestors. However, the author acknowledges the potential threat of extinction due to the relentless hunting practices of whalers.
# Embedding dimension: 768
#
# Chunk 60 Summary:
# In the past, whale populations were more abundant and dispersed, but now they have aggregated into vast armies, making hunting more challenging. Despite concerns about declining whale populations, the author argues that whales are resilient and will likely outlast human hunting due to their vast habitat and longevity.
# Embedding dimension: 768
#
# Chunk 61 Summary:
# Ahab's enigmatic nature is revealed as he interacts with the carpenter, who is making him a new leg. Ahab's philosophical musings on the nature of existence and the possibility of unseen forces lead him to question the carpenter's sanity. Meanwhile, Starbuck confronts Ahab about an oil leak in the ship's hold, but Ahab dismisses his concerns, prioritizing his own obsession with hunting the white whale.
# Embedding dimension: 768
#
# Chunk 62 Summary:
# During a whaling voyage, the pagan harpooneer Queequeg falls ill and prepares for death, requesting a special coffin resembling a canoe. Despite his apparent acceptance of his fate, Queequeg rallies and recovers, using his coffin as a sea chest and carving it with intricate designs. Meanwhile, Captain Ahab remains obsessed with his pursuit of the white whale, his determination intensifying as the ship enters the Pacific Ocean.
# Embedding dimension: 768
#
# Chunk 63 Summary:
# A blacksmith named Perth, driven to despair by a tragic loss, finds solace in forging a harpoon for Captain Ahab's obsessive hunt for the white whale. Despite his past suffering, Perth's skill and determination remain unwavering, as he creates a weapon that will ultimately be used in the fateful encounter with the elusive creature.
# Embedding dimension: 768
#
# Chunk 64 Summary:
# The Pequod encounters the Bachelor, a ship filled with joy and success, while the Pequod remains somber and foreboding. Ahab, the Pequod's captain, is haunted by visions of a white whale and believes he will die at sea. Despite the contrast, the Pequod kills four whales, and Ahab observes the dying whale's head turning towards the sun, symbolizing faith and the inevitability of death.
# Embedding dimension: 768
#
# Chunk 65 Summary:
# During a typhoon, the Pequod's crew witnesses the eerie sight of St. Elmo's fire on the ship's masts, which Stubb interprets as a sign of good luck. Meanwhile, Ahab, standing before the flames, defiantly challenges the power of the "clear spirit" he once worshipped, declaring his own indomitable will and questioning the spirit's origins. Despite Starbuck's pleas to abandon the ill-fated voyage, Ahab remains resolute, extinguishing the flame on his harpoon as a symbol of his unwavering determination.
# Embedding dimension: 768
#
# Chunk 66 Summary:
# During a violent storm, Captain Ahab's crew is terrified by his reckless behavior and the malfunctioning of the ship's compasses. Starbuck, the first mate, contemplates killing Ahab to prevent further harm but ultimately decides against it. Despite the reversed compasses, Ahab uses his own magnetized needle to navigate the ship, demonstrating his unwavering determination and control over the elements.
# Embedding dimension: 768
#
# Chunk 67 Summary:
# As the Pequod approaches the Equator, a haunting cry from the sea is interpreted as a portent of doom. Despite the loss of a sailor who falls from the mast, the crew replaces the lifebuoy with Queequeg's coffin, transforming it into a symbol of both life and death. Ahab, driven by his obsession with the White Whale, encounters the Rachel, which brings news of the whale's sighting and the disappearance of one of its boats.
# Embedding dimension: 768
#
# Chunk 68 Summary:
# During a whaling expedition, Captain Ahab refuses to assist a stranger searching for his missing son, despite the stranger's pleas. Meanwhile, Ahab remains fixated on his own hunt for Moby Dick, his obsession dominating the crew. Despite his constant presence on deck, Ahab's true intentions remain hidden beneath his slouched hat, while the enigmatic Parsee Fedallah silently watches him.
# Embedding dimension: 768
#
# Chunk 69 Summary:
# Despite his distrust of Starbuck, Ahab appoints him as his watchman, a strange choice given Starbuck's previous opposition. Ahab's hat is taken by a hawk, an omen that is interpreted as a sign of his impending doom. The Pequod encounters the Delight, a ship that has lost five crew members to a whale attack, and Ahab vows to kill the white whale that caused their deaths.
# Embedding dimension: 768
#
# Chunk 70 Summary:
# After spotting Moby Dick, Captain Ahab and his crew launch their boats to pursue the whale. Despite their initial success, Moby Dick attacks and destroys Ahab's boat, leaving him stranded in the water. The Pequod intervenes, rescuing Ahab and his crew, but the chase continues with the whale still at large.
# Embedding dimension: 768
#
# Chunk 71 Summary:
# Captain Ahab relentlessly pursues the white whale, Moby Dick, despite warnings from his crew. As the third day of the chase begins, Ahab remains perched high on the mast, determined to find the whale. The crew lowers the boats, but sharks follow them, symbolizing the dangers they face. Ahab's unwavering determination and the ominous presence of the sharks foreshadow the impending climax of the chase.
# Embedding dimension: 768
#
# Chunk 72 Summary:
# During the final confrontation with Moby Dick, Ahab's boat is destroyed, and he is thrown into the sea. The whale attacks the Pequod, sinking it and killing all but Ishmael, who survives by clinging to a coffin-like buoy. The ship's wreckage and the whale's body disappear into the depths, leaving only a swirling vortex and a red flag nailed to a broken mast.
# Embedding dimension: 768
#
# Chunk 73 Summary:
# Rachel's search for her missing children led her to find another orphan. This book was adapted from the original text obtained from the Gutenberg Project and typeset using XETEX.
# Embedding dimension: 768

# %% [markdown]
# # Saving the embaddings and the summaries

# %%
import faiss
import numpy as np
import json

# Convert embeddings to a numpy array
embedding_dim = len(embeddings[0])
embedding_matrix = np.array(embeddings).astype('float32')

# Initialize FAISS index
index = faiss.IndexFlatL2(embedding_dim)

# Add embeddings to FAISS index
index.add(embedding_matrix)

# Save the index to disk
faiss.write_index(index, 'faiss_book_index.index')

# Save summaries to a JSON file
with open('summaries.json', 'w') as f:
    json.dump(summaries, f)

# %% [markdown]
# # Processing queries

# %%
class DocumentRetrievalSystem:
    def __init__(
        self, 
        faiss_index_path: str,
        summaries_path: str,
        gemini_api_key: str,
        embedding_model: str = "models/embedding-001",
        num_results: int = 3
    ):
        """
        Initialize the retrieval system with necessary components.
        
        Args:
            faiss_index_path: Path to saved FAISS index
            summaries_path: Path to saved summaries JSON
            gemini_api_key: API key for Google Gemini
            embedding_model: Model to use for query embedding
            num_results: Number of relevant documents to retrieve
        """
        # Load FAISS index
        self.index = faiss.read_index(faiss_index_path)
        
        # Load summaries
        with open(summaries_path, 'r') as f:
            self.summaries = json.load(f)
            

        
        self.model = GoogleGenerativeAI(
        model="models/gemini-1.5-flash",  # Correct model name format

        google_api_key=gemini_api_key
    )
    
        self.embedding_model = GoogleGenerativeAIEmbeddings(
            model="models/embedding-001",
            google_api_key=gemini_api_key
        )
    
        
        
        self.num_results = num_results

    def get_query_embedding(self, query: str) -> np.ndarray:
        """Generate embedding for the query text."""
        embedding = self.embedding_model.embed_query(
            query,
            task_type="retrieval_query"
        )
        return np.array(embedding).astype('float32').reshape(1, -1)

    def retrieve_relevant_documents(
        self, 
        query_embedding: np.ndarray
    ) -> Tuple[List[str], List[float]]:
        """
        Retrieve most relevant documents using FAISS.
        
        Returns:
            Tuple of (list of relevant summaries, list of distances)
        """
        # Search the index
        distances, indices = self.index.search(query_embedding, self.num_results)
        
        # Get corresponding summaries
        relevant_summaries = [self.summaries[idx] for idx in indices[0]]
        
        return relevant_summaries, distances[0]

    def format_context(
        self, 
        summaries: List[str], 
        distances: List[float]
    ) -> str:
        """Format retrieved documents into context for the LLM."""
        context_pieces = []
        for i, (summary, distance) in enumerate(zip(summaries, distances)):
            relevance_score = 1 / (1 + distance)  # Convert distance to similarity score
            context_pieces.append(
                f"Document {i+1} (Relevance: {relevance_score:.2f}):\n{summary}\n"
            )
        return "\n".join(context_pieces)

    def generate_response(
        self, 
        query: str, 
        context: str
    ) -> str:
        """Generate response using Gemini based on query and context."""
        prompt = f"""
        Based on the following context, please answer the user's question.
        Be specific and only use information from the provided context.
        If the context doesn't contain relevant information, please say so.

        Context:
        {context}

        User Question: {query}
        """
        print(context,'\n\n\n\n')
        print(query)
        
        response = self.model.invoke(prompt)
        return response

    def process_query(self, query: str) -> str:
        """
        Main method to process a user query and return a response.
        
        Args:
            query: User's question
            
        Returns:
            Generated response based on retrieved relevant documents
        """
        try:
            # Get query embedding
            query_embedding = self.get_query_embedding(query)
            
            # Retrieve relevant documents
            relevant_docs, distances = self.retrieve_relevant_documents(query_embedding)
            
            # Format context
            context = self.format_context(relevant_docs, distances)
            
            # Generate response
            response = self.generate_response(query, context)
            
            return response
            
        except Exception as e:
            return f"An error occurred: {str(e)}"

# Initialize the system
retrieval_system = DocumentRetrievalSystem(
    faiss_index_path='faiss_book_index.index',
    summaries_path='summaries.json',
    gemini_api_key=API_KEY
)

query = "who is Captain Ahab  ?"
response = retrieval_system.process_query(query)
print(response)
# Out:
# Document 1 (Relevance: 0.70):
# Captain Ahab, the enigmatic and formidable captain of the Pequod, is described as a complex and enigmatic figure. Despite his reputation as a skilled whaler and a stern leader, he is also known for his obsessive pursuit of the white whale, Moby Dick, which cost him his leg. While some crew members express concern about his mental state, others remain loyal, recognizing his determination and leadership qualities.
#
# Document 2 (Relevance: 0.69):
# Rachel's search for her missing children led her to find another orphan. This book was adapted from the original text obtained from the Gutenberg Project and typeset using XETEX.
#
# Document 3 (Relevance: 0.68):
# In the whaling industry, the captain stands while being rowed, unlike other ships where they sit comfortably. The Town-Ho, a whaling ship, encountered the Pequod and shared news of Moby Dick, including a mysterious and ominous incident involving the captain and a crew member. This secret, known only to a few sailors on the Pequod, would later play a significant role in the tragedy that unfolded.
#
#
#
#
#
# who is Captain Ahab  ?
# Captain Ahab is the enigmatic and formidable captain of the Pequod, known for his skill as a whaler and his stern leadership. He is also known for his obsessive pursuit of the white whale, Moby Dick, which cost him his leg.
